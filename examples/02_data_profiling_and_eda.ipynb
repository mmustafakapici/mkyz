# %% [markdown]
# # Data Profiling & EDA
#
# Discover insights about your data automatically using MKYZ's profiling tools.

# %%
import mkyz
mkyz.init()
# Out:
# mkyz package initialized. Version: 0.2.0
# mkyz package initialized. Version: 0.2.0

# %% [markdown]
# ## 1. Load Titanic Dataset
#
# This dataset contains mixed types (numeric, categorical) and missing values.

# %%
df = mkyz.load_data('data/titanic.csv')
print(f"Loaded {len(df)} rows.")
# Out:
# Loaded 891 rows.

# %% [markdown]
# ## 2. Quick Info
#
# Get immediate statistics about memory usage and types.

# %%
info = mkyz.data_info(df)
print(f"Missing Data: {info['missing_pct']}%")
print(f"Columns: {info['columns']}")
# Out:
# Missing Data: 8.1%
# Columns: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %% [markdown]
# ## 3. Quick EDA Report
#
# Generate a console-based report with recommendations.

# %%
# 'survived' is the target column
mkyz.quick_eda(df, target_column='survived')
# Out:
# ============================================================
# DATA PROFILE SUMMARY
# ============================================================
#
# 📊 Overview
# ----------------------------------------
#   Rows: 891
#   Columns: 12
#   Memory: 0.31 MB
#
# 📈 Column Types
# ----------------------------------------
#   Numerical: 7
#   Categorical: 5
#   Datetime: 0
#   Boolean: 0
#
# ❓ Missing Values
# ----------------------------------------
#   Total: 866 (8.10%)
#   Columns affected: 3
#   Complete rows: 183
#
# 🔄 Duplicates
# ----------------------------------------
#   Duplicate rows: 0
#
# ============================================================
#
# 💡 RECOMMENDATIONS
# ----------------------------------------
#   ⚠️ High missing rate (8.1%). Consider imputation or dropping columns with >50% missing.
#   ⚠️ Column 'Name' has high cardinality (891 unique). Consider target encoding or grouping rare categories.
#   ⚠️ Column 'Ticket' has high cardinality (681 unique). Consider target encoding or grouping rare categories.
#   ⚠️ Column 'Cabin' has high cardinality (147 unique). Consider target encoding or grouping rare categories.
#   ⚠️ Column 'SibSp' has 5.2% outliers. Consider capping or investigation.
#   ⚠️ Column 'Parch' has 23.9% outliers. Consider capping or investigation.
#   ⚠️ Column 'Fare' has 13.0% outliers. Consider capping or investigation.

# %% [markdown]
# ## 4. Advanced Profiling
#
# Deep dive into the data using the `DataProfile` class.

# %%
profile = mkyz.DataProfile(df, target_column='survived')

# Check recommendations
print("Recommendations:")
for rec in profile.get_recommendations():
    print(f"- {rec}")
# Out:
# Recommendations:
# - ⚠️ High missing rate (8.1%). Consider imputation or dropping columns with >50% missing.
# - ⚠️ Column 'Name' has high cardinality (891 unique). Consider target encoding or grouping rare categories.
# - ⚠️ Column 'Ticket' has high cardinality (681 unique). Consider target encoding or grouping rare categories.
# - ⚠️ Column 'Cabin' has high cardinality (147 unique). Consider target encoding or grouping rare categories.
# - ⚠️ Column 'SibSp' has 5.2% outliers. Consider capping or investigation.
# - ⚠️ Column 'Parch' has 23.9% outliers. Consider capping or investigation.
# - ⚠️ Column 'Fare' has 13.0% outliers. Consider capping or investigation.

# %% [markdown]
# ## 5. Export Report
#
# Save the analysis as a shareable HTML file.

# %%
profile.export_report('titanic_eda_report.html')
print("Report saved!")
# Out:
# Report saved!
