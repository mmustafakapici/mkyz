# %% [markdown]
# # AutoML & Optimization
#
# Let MKYZ find the best model for your data.

# %%
import mkyz
mkyz.init()
# Out:
# mkyz package initialized. Version: 0.2.0
# mkyz package initialized. Version: 0.2.0

# %% [markdown]
# ## 1. Load Diabetes Data
#
# A standard classification dataset.

# %%
df = mkyz.load_data('data/diabetes.csv')
X = df.drop('outcome', axis=1)
y = df['outcome']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 df = mkyz.load_data('data/diabetes.csv')
# ----> 2 X = df.drop('outcome', axis=1)
#       3 y = df['outcome']
#
# File c:\Users\mmust\anaconda3\envs\mkyz\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\mmust\anaconda3\envs\mkyz\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\mmust\anaconda3\envs\mkyz\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\mmust\anaconda3\envs\mkyz\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['outcome'] not found in axis"

# %% [markdown]
# ## 2. Auto Train
#
# Automatically train and compare multiple models.

# %%
# Run models and get leaderboard
results = mkyz.auto_train(X, y, task='classification', timeout=30)

print(f"Best Model: {results['best_model_name']}")
print(f"Score: {results['best_score']:.4f}")

# %% [markdown]
# ## 3. Hyperparameter Optimization
#
# Optimize a specific model using Grid Search or Bayesian Optimization.

# %%
from sklearn.ensemble import RandomForestClassifier

base_model = RandomForestClassifier()
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 10]
}

# Note: 'method' can be 'grid', 'random', or 'bayesian'
opt_model, best_params = mkyz.optimize_model(
    base_model, 
    X, y, 
    param_grid=param_grid, 
    method='random', 
    n_trials=10
)

print("Best Params:", best_params)
